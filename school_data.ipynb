# %%
import pandas as pd
school_df = pd.read_csv('./data/fixed_effects/school_data.csv', on_bad_lines='skip')
school_df
# Out:
#                                             Agency Name  \
# 0                          A W BROWN LEADERSHIP ACADEMY
# 1                                            A+ ACADEMY
# 2                                A+ UNLIMITED POTENTIAL
# 3                                            ABBOTT ISD
# 4                                           ABC UNIFIED
# ...                                                 ...
# 3684  Data Source: U.S. Department of Education Nati...
# 3685                                                NaN
# 3686      † indicates that the data are not applicable.
# 3687             – indicates that the data are missing.
# 3688  ‡ indicates that the data do not meet NCES dat...
#
#      State Name [District] Latest available year  \
# 0                                          Texas
# 1                                          Texas
# 2                                          TEXAS
# 3                                          Texas
# ...

# %%
len(school_df[school_df["County Name [District] 2022-23"] == "Travis County"])
# Out:
# 38

# %%
len(school_df[school_df["County Name [District] 2022-23"] == "Santa Clara County"])
# Out:
# 85

# %%
len(school_df[school_df["County Name [District] 2022-23"] == "San Mateo County"])
# Out:
# 38

# %%
len(school_df[school_df["County Name [District] 2022-23"] == "Fresno County"])
# Out:
# 62
