# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Santa Clara versus Fresno

# %%
def graph_labor(df):
    df["Year-Month"] = pd.to_datetime(df["Year-Month"])
    # sns.set_theme(style="whitegrid")
    plt.figure(figsize=(12, 6))
    sns.lineplot(x="Year-Month", y="Employment", data=df, marker="o")
    plt.title("Employment Over Time")
    plt.xlabel("Year")
    plt.ylabel("Employment")
    plt.xticks(rotation=45)
    plt.show()

def graph_real_estate(df):
    df["Date"] = pd.to_datetime(df["Date"])
    sns.set_theme()
    plt.figure(figsize=(14, 7))
    sns.lineplot(x="Date", y="Price", data=df, marker="o")
    plt.title("Price Trend Over Time")
    plt.xlabel("Year")
    plt.ylabel("Price")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Fresno employment and real estate graphs
fresno_employment = pd.read_csv("./data/processed_employment/Fresno_County,_California.csv")
fresno_real_estate = pd.read_csv("./data/processed_zillow/Fresno_County.csv")

graph_labor(fresno_employment)
graph_real_estate(fresno_real_estate)

print(fresno_employment.describe())
print(fresno_real_estate.describe())
# Out:
#                           Year-Month   Employment
# count                            159   159.000000
# mean   2017-07-31 23:14:43.018867968  3309.949686
# min              2011-01-01 00:00:00     0.000000
# 25%              2014-04-16 00:00:00  3113.500000
# 50%              2017-08-01 00:00:00  3501.000000
# 75%              2020-11-16 00:00:00  3756.500000
# max              2024-03-01 00:00:00  3982.000000
# std                              NaN   758.987874
#                                 Date          Price
# count                            165     165.000000
# mean   2017-10-31 06:50:10.909090816  252683.593939
# min              2011-01-01 00:00:00  138997.000000
# 25%              2014-06-01 00:00:00  189172.000000
# 50%              2017-11-01 00:00:00  239554.000000
# 75%              2021-04-01 00:00:00  316048.000000
# max              2024-09-01 00:00:00  395622.000000
# std                              NaN   81946.606065

# %%
# Santa Clara employment and real estate graphs
sc_employment = pd.read_csv(
    "./data/processed_employment/Santa_Clara_County,_California.csv"
)
sc_real_estate = pd.read_csv("./data/processed_zillow/Santa_Clara_County.csv")

graph_labor(sc_employment)
graph_real_estate(sc_real_estate)

# %%
# Sant Mateo employment and real estate graphs
sm_employment = pd.read_csv(
    "./data/processed_employment/San_Mateo_County,_California.csv"
)
sm_real_estate = pd.read_csv("./data/processed_zillow/San_Mateo_County.csv")

graph_labor(sm_employment)
graph_real_estate(sm_real_estate)

# %%
import statsmodels.formula.api as smf

sc_real_estate["county"] = "Santa Clara"
fresno_real_estate["county"] = "Fresno"

# Concatenate dataframes
data = pd.concat([sc_real_estate, fresno_real_estate])

print(data)

data["treatment"] = data["county"].apply(lambda x: 1 if x == "Santa Clara" else 0)
# Define post variable based on intervention year, e.g., 2020
intervention_year = 2018
intervention_date = pd.to_datetime(f"{intervention_year}-01-01")
data["post"] = data["Date"].apply(lambda x: 1 if x >= intervention_date else 0)

# Interaction term for DiD
data["treatment_post"] = data["treatment"] * data["post"]

model = smf.ols(
    "Price ~ treatment + post + treatment_post", data=data
).fit()
print(model.summary())
# Out:
#           Date   Price       county
# 0   2011-01-01  504038  Santa Clara
# 1   2011-02-01  500356  Santa Clara
# 2   2011-03-01  498355  Santa Clara
# 3   2011-04-01  495651  Santa Clara
# 4   2011-05-01  491514  Santa Clara
# ..         ...     ...          ...
# 160 2024-05-01  393399       Fresno
# 161 2024-06-01  394698       Fresno
# 162 2024-07-01  395212       Fresno
# 163 2024-08-01  395480       Fresno
# 164 2024-09-01  395622       Fresno
#
# [330 rows x 3 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     1377.
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):          9.74e-185
# Time:                        10:44:51   Log-Likelihood:                -4332.7
# No. Observations:                 330   AIC:                             8673.
# Df Residuals:                     326   BIC:                             8689.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       1.851e+05   1.34e+04     13.835      0.000    1.59e+05    2.11e+05
# treatment       5.325e+05   1.89e+04     28.149      0.000    4.95e+05     5.7e+05
# post            1.378e+05   1.91e+04      7.215      0.000       1e+05    1.75e+05
# treatment_post  4.523e+05    2.7e+04     16.751      0.000    3.99e+05    5.05e+05
# ==============================================================================
# Omnibus:                        0.245   Durbin-Watson:                   0.099
# Prob(Omnibus):                  0.885   Jarque-Bera (JB):                0.374
# Skew:                          -0.029   Prob(JB):                        0.829
# Kurtosis:                       2.846   Cond. No.                         6.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.formula.api as smf

sc_real_estate["county"] = "Santa Clara"
sm_real_estate["county"] = "San Mateo"

# Concatenate dataframes
data = pd.concat([sc_real_estate, sm_real_estate])

print(data)

data["treatment"] = data["county"].apply(lambda x: 1 if x == "Santa Clara" else 0)
# Define post variable based on intervention year, e.g., 2020
intervention_year = 2018
intervention_date = pd.to_datetime(f"{intervention_year}-01-01")
data["post"] = data["Date"].apply(lambda x: 1 if x >= intervention_date else 0)

# Interaction term for DiD
data["treatment_post"] = data["treatment"] * data["post"]

model = smf.ols("Price ~ treatment + post + treatment_post", data=data).fit()
print(model.summary())
# Out:
#           Date    Price       county
# 0   2011-01-01   504038  Santa Clara
# 1   2011-02-01   500356  Santa Clara
# 2   2011-03-01   498355  Santa Clara
# 3   2011-04-01   495651  Santa Clara
# 4   2011-05-01   491514  Santa Clara
# ..         ...      ...          ...
# 160 2024-05-01  1531926    San Mateo
# 161 2024-06-01  1543690    San Mateo
# 162 2024-07-01  1548980    San Mateo
# 163 2024-08-01  1549801    San Mateo
# 164 2024-09-01  1549883    San Mateo
#
# [330 rows x 3 columns]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.757
# Method:                 Least Squares   F-statistic:                     343.3
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):          1.59e-100
# Time:                        10:45:13   Log-Likelihood:                -4438.7
# No. Observations:                 330   AIC:                             8885.
# Df Residuals:                     326   BIC:                             8901.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       8.595e+05   1.84e+04     46.604      0.000    8.23e+05    8.96e+05
# treatment       -1.42e+05   2.61e+04     -5.444      0.000   -1.93e+05   -9.07e+04
# post            5.741e+05   2.63e+04     21.808      0.000    5.22e+05    6.26e+05
# treatment_post  1.597e+04   3.72e+04      0.429      0.668   -5.73e+04    8.92e+04
# ==============================================================================
# Omnibus:                      129.087   Durbin-Watson:                   0.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.030
# Skew:                           0.048   Prob(JB):                     0.000122
# Kurtosis:                       1.859   Cond. No.                         6.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Out:
#           Date    Price       county Year-Month  Employment quarter  \
# 0   2011-01-01   504038  Santa Clara 2011-01-01     46346.0  2011Q1
# 1   2011-02-01   500356  Santa Clara 2011-02-01     46806.0  2011Q1
# 2   2011-03-01   498355  Santa Clara 2011-03-01     46824.0  2011Q1
# 3   2011-04-01   495651  Santa Clara 2011-04-01     47189.0  2011Q2
# 4   2011-05-01   491514  Santa Clara 2011-05-01     47737.0  2011Q2
# ..         ...      ...          ...        ...         ...     ...
# 160 2024-05-01  1544915  Santa Clara        NaT         NaN  2024Q2
# 161 2024-06-01  1560453  Santa Clara        NaT         NaN  2024Q2
# 162 2024-07-01  1575459  Santa Clara        NaT         NaN  2024Q3
# 163 2024-08-01  1588747  Santa Clara        NaT         NaN  2024Q3
# 164 2024-09-01  1601205  Santa Clara        NaT         NaN  2024Q3
#
#      quarter_2011Q2  quarter_2011Q3  quarter_2011Q4  quarter_2012Q1  ...  \
# 0             False           False           False           False  ...
# 1             False           False           False           False  ...
# 2             False           False           False           False  ...
# 3              True           False           False           False  ...
# 4              True           False           False           False  ...
# ..              ...             ...             ...             ...  ...
# 160           False           False           False           False  ...
# 161           False           False           False           False  ...
# 162           False           False           False           False  ...
# 163           False           False           False           False  ...
# 164           False           False           False           False  ...
#
#      quarter_2022Q2  quarter_2022Q3  quarter_2022Q4  quarter_2023Q1  \
# 0             False           False           False           False
# 1             False           False           False           False
# 2             False           False           False           False
# 3             False           False           False           False
# 4             False           False           False           False
# ..              ...             ...             ...             ...
# 160           False           False           False           False
# 161           False           False           False           False
# 162           False           False           False           False
# 163           False           False           False           False
# 164           False           False           False           False
#
#      quarter_2023Q2  quarter_2023Q3  quarter_2023Q4  quarter_2024Q1  \
# 0             False           False           False           False
# 1             False           False           False           False
# 2             False           False           False           False
# 3             False           False           False           False
# 4             False           False           False           False
# ..              ...             ...             ...             ...
# 160           False           False           False           False
# 161           False           False           False           False
# 162           False           False           False           False
# 163           False           False           False           False
# 164           False           False           False           False
#
#      quarter_2024Q2  quarter_2024Q3
# 0             False           False
# 1             False           False
# 2             False           False
# 3             False           False
# 4             False           False
# ..              ...             ...
# 160            True           False
# 161            True           False
# 162           False            True
# 163           False            True
# 164           False            True
#
# [165 rows x 60 columns]
#                   Date    Price Year-Month  Employment quarter  \
# county
# Santa Clara 2011-01-01   504038 2011-01-01     46346.0  2011Q1
# Santa Clara 2011-02-01   500356 2011-02-01     46806.0  2011Q1
# Santa Clara 2011-03-01   498355 2011-03-01     46824.0  2011Q1
# Santa Clara 2011-04-01   495651 2011-04-01     47189.0  2011Q2
# Santa Clara 2011-05-01   491514 2011-05-01     47737.0  2011Q2
# ...                ...      ...        ...         ...     ...
# Santa Clara 2024-05-01  1544915        NaT         NaN  2024Q2
# Santa Clara 2024-06-01  1560453        NaT         NaN  2024Q2
# Santa Clara 2024-07-01  1575459        NaT         NaN  2024Q3
# Santa Clara 2024-08-01  1588747        NaT         NaN  2024Q3
# Santa Clara 2024-09-01  1601205        NaT         NaN  2024Q3
#
#              quarter_2011Q2  quarter_2011Q3  quarter_2011Q4  quarter_2012Q1  \
# county
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara            True           False           False           False
# Santa Clara            True           False           False           False
# ...                     ...             ...             ...             ...
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
#
#              quarter_2012Q2  ...  quarter_2022Q2  quarter_2022Q3  \
# county                       ...
# Santa Clara           False  ...           False           False
# Santa Clara           False  ...           False           False
# Santa Clara           False  ...           False           False
# Santa Clara           False  ...           False           False
# Santa Clara           False  ...           False           False
# ...                     ...  ...             ...             ...
# Santa Clara           False  ...           False           False
# Santa Clara           False  ...           False           False
# Santa Clara           False  ...           False           False
# Santa Clara           False  ...           False           False
# Santa Clara           False  ...           False           False
#
#              quarter_2022Q4  quarter_2023Q1  quarter_2023Q2  quarter_2023Q3  \
# county
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# ...                     ...             ...             ...             ...
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
#
#              quarter_2023Q4  quarter_2024Q1  quarter_2024Q2  quarter_2024Q3
# county
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# Santa Clara           False           False           False           False
# ...                     ...             ...             ...             ...
# Santa Clara           False           False            True           False
# Santa Clara           False           False            True           False
# Santa Clara           False           False           False            True
# Santa Clara           False           False           False            True
# Santa Clara           False           False           False            True
#
# [165 rows x 59 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 26
#      23 formula = f'Price ~ Employment + {time_fixed_effects}'
#      25 # Fit the fixed effects model with both entity (county) and time fixed effects
# ---> 26 model = PanelOLS.from_formula(formula, data=data)
#      27 fe_results = model.fit()
#      29 print(fe_results)
#
# File /opt/homebrew/lib/python3.11/site-packages/linearmodels/panel/model.py:1460, in PanelOLS.from_formula(cls, formula, data, weights, other_effects, singletons, drop_absorbed, check_rank)
#    1402 @classmethod
#    1403 def from_formula(
#    1404     cls,
#    (...)
#    1412     check_rank: bool = True,
#    1413 ) -> PanelOLS:
#    1414     """
#    1415     Create a model from a formula
#    1416
#    (...)
#    1458     >>> res = mod.fit(cov_type="clustered", cluster_entity=True)
#    1459     """
# -> 1460     parser = PanelFormulaParser(formula, data, context=capture_context(1))
#    1461     entity_effect = parser.entity_effect
#    1462     time_effect = parser.time_effect
#
# File /opt/homebrew/lib/python3.11/site-packages/linearmodels/panel/model.py:166, in PanelFormulaParser.__init__(self, formula, data, eval_env, context)
#     158 def __init__(
#     159     self,
#     160     formula: str,
#    (...)
#     163     context: Mapping[str, Any] | None = None,
#     164 ) -> None:
#     165     self._formula = formula
# --> 166     self._data = PanelData(data, convert_dummies=False, copy=False)
#     167     self._na_action = NAAction("ignore")
#     168     self._eval_env = eval_env
#
# File /opt/homebrew/lib/python3.11/site-packages/linearmodels/panel/data.py:227, in PanelData.__init__(self, x, var_name, convert_dummies, drop_first, copy)
#     225     else:
#     226         options = {"future_stack": True} if PD_GTE_21 else {"dropna": False}
# --> 227         self._frame = DataFrame({var_name: x.T.stack(**options)})
#     228 elif isinstance(x, np.ndarray):
#     229     if x.ndim not in (2, 3):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:9718, in DataFrame.stack(self, level, dropna, sort, future_stack)
#    9716         level = [level]
#    9717     level = [self.columns._get_level_number(lev) for lev in level]
# -> 9718     result = stack_v3(self, level)
#    9720 return result.__finalize__(self, method="stack")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:887, in stack_v3(frame, level)
#     885 def stack_v3(frame: DataFrame, level: list[int]) -> Series | DataFrame:
#     886     if frame.columns.nunique() != len(frame.columns):
# --> 887         raise ValueError("Columns with duplicate values are not supported in stack")
#     889     # If we need to drop `level` from columns, it needs to be in descending order
#     890     drop_levnums = sorted(level, reverse=True)
#
# ValueError: Columns with duplicate values are not supported in stack
