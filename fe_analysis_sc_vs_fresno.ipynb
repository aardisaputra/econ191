# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from linearmodels.panel import PanelOLS
from stargazer.stargazer import Stargazer

# %%
sc_employment = pd.read_csv(
    "./data/processed_employment/Santa_Clara_County,_California.csv"
)
sc_real_estate = pd.read_csv("./data/processed_zillow/Santa_Clara_County.csv")

data = sc_real_estate
data = pd.concat([data, sc_employment], axis=1)
data = data.dropna(subset=["Year-Month"])
data["county"] = "Santa Clara"
data["constant"] = 1
data["Date"] = pd.to_datetime(data["Date"])
data["Year"] = data["Date"].dt.year
data["Quarter"] = data["Date"].dt.quarter
data["Year_Quarter"] = data["Year"].astype(str) + "Q" + data["Quarter"].astype(str)
year_quarter_dummies = pd.get_dummies(
    data["Year_Quarter"], prefix="YQ", drop_first=True
)
data = pd.concat([data, year_quarter_dummies], axis=1)

data = data.set_index(["county", "Date"])

model = PanelOLS(data.Price, data[["Employment"] + ["constant"]])
# mod = PanelOLS(
#     data.Price,
#     data[["Employment"] + year_quarter_dummies.columns.tolist() + ["constant"]],
# )
res = model.fit()
# Extract results
coef = res.params
pvalues = res.pvalues
stderr = res.std_errors
rsquared = res.rsquared

# Build a LaTeX table manually
latex_table = r"""
\begin{table}[!htbp] \centering
  \caption{Regression Results}
\begin{tabular}{@{\extracolsep{5pt}}lccc}
\\[-1.8ex]\hline
\hline \\[-1.8ex]
Variable & Coefficient & Std. Error & P-Value \\
\hline \\[-1.8ex]
"""

# Loop through coefficients
for var in coef.index:
    latex_table += f"{var} & {coef[var]:.4f} & {stderr[var]:.4f} & {pvalues[var]:.4f} \\\\\n"

# Add R-squared and adjusted R-squared
latex_table += r"""
\hline \\[-1.8ex]
$R^2$ & \multicolumn{3}{c}{""" + f"{rsquared:.4f}" + r"""} \\
\hline
\end{tabular}
\end{table}
"""

# Print the LaTeX table
print(latex_table)
# Out:
# \begin{table}[!htbp] \centering
#   \caption{Regression Results}
# \begin{tabular}{@{\extracolsep{5pt}}lccc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
# Variable & Coefficient & Std. Error & P-Value \\
# \hline \\[-1.8ex]
# Employment & 15.2989 & 0.5296 & 0.0000 \\
# constant & -255724.3993 & 44225.6306 & 0.0000 \\
#
# \hline \\[-1.8ex]
# $R^2$ & \multicolumn{3}{c}{0.8416} \\
# \hline
# \end{tabular}
# \end{table}

# %%
sc_employment = pd.read_csv(
    "./data/processed_employment/Santa_Clara_County,_California.csv"
)
sc_real_estate = pd.read_csv("./data/processed_zillow/Santa_Clara_County.csv")

data = sc_real_estate
data = pd.concat([data, sc_employment], axis=1)
data = data.dropna(subset=["Year-Month"])
data["county"] = "Santa Clara"
data["constant"] = 1
data["Date"] = pd.to_datetime(data["Date"])
data["Year"] = data["Date"].dt.year
data["Quarter"] = data["Date"].dt.quarter
data["Year_Quarter"] = data["Year"].astype(str) + "Q" + data["Quarter"].astype(str)
year_quarter_dummies = pd.get_dummies(
    data["Year_Quarter"], prefix="YQ", drop_first=True
)
data = pd.concat([data, year_quarter_dummies], axis=1)

data = data.set_index(["county", "Date"])

# mod = PanelOLS(data.Price, data[["Employment"] + ["constant"]])
mod = PanelOLS(
    data.Price,
    data[["Employment"] + year_quarter_dummies.columns.tolist() + ["constant"]],
)
res = mod.fit()

# Extract results
coef = res.params
pvalues = res.pvalues
stderr = res.std_errors
rsquared = res.rsquared
r_squared_between = res.rsquared_between
print("R-squared (Between):", r_squared_between)

# Build a LaTeX table manually
latex_table = r"""
\begin{table}[!htbp] \centering
  \caption{Regression Results}
\begin{tabular}{@{\extracolsep{5pt}}lccc}
\\[-1.8ex]\hline
\hline \\[-1.8ex]
Variable & Coefficient & Std. Error & P-Value \\
\hline \\[-1.8ex]
"""

# Loop through coefficients
for var in coef.index:
    latex_table += f"{var} & {coef[var]:.4f} & {stderr[var]:.4f} & {pvalues[var]:.4f} \\\\\n"

# Add R-squared and adjusted R-squared
latex_table += r"""
\hline \\[-1.8ex]
$R^2$ & \multicolumn{3}{c}{""" + f"{rsquared:.4f}" + r"""} \\
\hline
"""

latex_table += f"R-squared (Between) & \\multicolumn{{3}}{{c}}{{{r_squared_between:.4f}}} \\\\ \\hline\n"

latex_table += r"""
\end{tabular}
\end{table}
"""

# Print the LaTeX table
print(latex_table)
# Out:
# R-squared (Between): 0.0
#
# \begin{table}[!htbp] \centering
#   \caption{Regression Results}
# \begin{tabular}{@{\extracolsep{5pt}}lccc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
# Variable & Coefficient & Std. Error & P-Value \\
# \hline \\[-1.8ex]
# Employment & 3.1236 & 1.5989 & 0.0534 \\
# YQ_2011Q2 & -12563.7221 & 12443.5304 & 0.3150 \\
# YQ_2011Q3 & -22400.0918 & 13455.8624 & 0.0990 \\
# YQ_2011Q4 & -31767.7613 & 13513.7935 & 0.0206 \\
# YQ_2012Q1 & -26689.3682 & 12908.6458 & 0.0411 \\
# YQ_2012Q2 & -13469.3269 & 13292.0666 & 0.3132 \\
# YQ_2012Q3 & 13806.4808 & 14165.4923 & 0.3320 \\
# YQ_2012Q4 & 60856.6311 & 14203.7413 & 0.0000 \\
# YQ_2013Q1 & 76655.7621 & 19931.6819 & 0.0002 \\
# YQ_2013Q2 & 85350.4062 & 21196.3055 & 0.0001 \\
# YQ_2013Q3 & 107935.0871 & 24259.0025 & 0.0000 \\
# YQ_2013Q4 & 139438.0965 & 25414.5420 & 0.0000 \\
# YQ_2014Q1 & 157503.2841 & 27352.7007 & 0.0000 \\
# YQ_2014Q2 & 155990.6894 & 30840.0945 & 0.0000 \\
# YQ_2014Q3 & 159239.2886 & 36286.8333 & 0.0000 \\
# YQ_2014Q4 & 193015.8163 & 37248.2296 & 0.0000 \\
# YQ_2015Q1 & 221177.9700 & 40808.5341 & 0.0000 \\
# YQ_2015Q2 & 227690.9044 & 44116.8364 & 0.0000 \\
# YQ_2015Q3 & 244905.3451 & 49091.6833 & 0.0000 \\
# YQ_2015Q4 & 285900.8989 & 50062.6359 & 0.0000 \\
# YQ_2016Q1 & 333017.1556 & 41098.4382 & 0.0000 \\
# YQ_2016Q2 & 327826.4044 & 43348.8309 & 0.0000 \\
# YQ_2016Q3 & 292486.1534 & 47971.5115 & 0.0000 \\
# YQ_2016Q4 & 267627.5173 & 49599.2137 & 0.0000 \\
# YQ_2017Q1 & 278210.9956 & 55157.0289 & 0.0000 \\
# YQ_2017Q2 & 311259.5592 & 58535.7981 & 0.0000 \\
# YQ_2017Q3 & 304988.8446 & 65956.6180 & 0.0000 \\
# YQ_2017Q4 & 310483.8118 & 65041.9328 & 0.0000 \\
# YQ_2018Q1 & 375940.8142 & 65368.0668 & 0.0000 \\
# YQ_2018Q2 & 490611.7618 & 69567.2416 & 0.0000 \\
# YQ_2018Q3 & 543600.0175 & 76021.2898 & 0.0000 \\
# YQ_2018Q4 & 567745.7220 & 77131.9101 & 0.0000 \\
# YQ_2019Q1 & 536507.6727 & 78099.2393 & 0.0000 \\
# YQ_2019Q2 & 470034.1992 & 83152.1128 & 0.0000 \\
# YQ_2019Q3 & 432534.7252 & 90775.0388 & 0.0000 \\
# YQ_2019Q4 & 438903.9276 & 91327.9867 & 0.0000 \\
# YQ_2020Q1 & 456503.1816 & 93338.0134 & 0.0000 \\
# YQ_2020Q2 & 464640.2682 & 92875.1893 & 0.0000 \\
# YQ_2020Q3 & 451710.3610 & 93818.8436 & 0.0000 \\
# YQ_2020Q4 & 509792.5870 & 93465.3500 & 0.0000 \\
# YQ_2021Q1 & 563911.3283 & 92895.7936 & 0.0000 \\
# YQ_2021Q2 & 605021.1203 & 92616.3214 & 0.0000 \\
# YQ_2021Q3 & 651671.4309 & 94690.2583 & 0.0000 \\
# YQ_2021Q4 & 691913.4538 & 94762.6622 & 0.0000 \\
# YQ_2022Q1 & 799830.7766 & 87989.0918 & 0.0000 \\
# YQ_2022Q2 & 881311.4958 & 92756.8481 & 0.0000 \\
# YQ_2022Q3 & 846099.5989 & 87743.6801 & 0.0000 \\
# YQ_2022Q4 & 783316.5764 & 83526.9407 & 0.0000 \\
# YQ_2023Q1 & 753013.8929 & 80623.1609 & 0.0000 \\
# YQ_2023Q2 & 732307.6544 & 77102.9686 & 0.0000 \\
# YQ_2023Q3 & 782174.7777 & 78123.4527 & 0.0000 \\
# YQ_2023Q4 & 853830.2058 & 76695.7138 & 0.0000 \\
# YQ_2024Q1 & 870119.3528 & 74723.3967 & 0.0000 \\
# constant & 355174.0557 & 75102.4223 & 0.0000 \\
#
# \hline \\[-1.8ex]
# $R^2$ & \multicolumn{3}{c}{0.9986} \\
# \hline
# \end{tabular}
# \end{table}
# R-squared (Between) & \multicolumn{3}{c}{0.0000} \\ \hline

# %%
fixed_effects = pd.read_csv("./data/fixed_effects/Environment.csv")
fixed_effects['Schools'] = [85, 38, 62, 32]
fixed_effects
# Out:
#                County  Average Temperature  Precipitation  Palmer Z-index  \
# 0  Santa Clara County                 61.4           4.34            1.57
# 1    San Mateo County                 58.4           5.65            0.43
# 2       Fresno County                 58.3           4.80            1.53
# 3       Travis County                 70.1          10.14            1.92
#
#    Schools
# 0       85
# 1       38
# 2       62
# 3       32

# %%
sc_employment = pd.read_csv(
    "./data/processed_employment/Santa_Clara_County,_California.csv"
)
sc_real_estate = pd.read_csv("./data/processed_zillow/Santa_Clara_County.csv")
fresno_employment = pd.read_csv("./data/processed_employment/Fresno_County,_California.csv")
fresno_real_estate = pd.read_csv("./data/processed_zillow/Fresno_County.csv")

travis_employment = pd.read_csv("./data/processed_employment/Travis_County,_Texas.csv")
travis_real_estate = pd.read_csv("./data/processed_zillow/Travis_County.csv")


sc_data = pd.concat([sc_real_estate, sc_employment], axis=1)
sc_data["county"] = "Santa Clara"

fresno_data = pd.concat([fresno_real_estate, fresno_employment], axis=1)
fresno_data["county"] = "Fresno"

travis_data = pd.concat([travis_real_estate, travis_employment], axis=1)
travis_data["county"] = "Travis"

data = pd.concat([sc_data, fresno_data, travis_data], axis=0)
data = data.dropna(subset=["Year-Month"])

data["Date"] = pd.to_datetime(data["Date"])


data["Year"] = data["Date"].dt.year
data["Quarter"] = data["Date"].dt.quarter
data["Year_Quarter"] = data["Year"].astype(str) + "Q" + data["Quarter"].astype(str)

year_quarter_dummies = pd.get_dummies(
    data["Year_Quarter"], prefix="YQ", drop_first=True
)

data = pd.concat([data, year_quarter_dummies], axis=1)

print(data)

data = data.set_index(["county", "Date"])

print(data)

# mod = PanelOLS(data.Price, data[["Employment"] + ["constant"]])
mod = PanelOLS(
    data.Price,
    data[["Employment"] + year_quarter_dummies.columns.tolist()],  # Time-varying variables only
    entity_effects=True,  # Absorbs county-level fixed effects
    drop_absorbed=True    # Automatically drops variables perfectly collinear with fixed effects
)
res = mod.fit()

print(res)

# Extract results
coef = res.params
pvalues = res.pvalues
stderr = res.std_errors
rsquared = res.rsquared
r_squared_between = res.rsquared_between
print("R-squared (Between):", r_squared_between)

# Build a LaTeX table manually
latex_table = r"""
\begin{table}[!htbp] \centering
  \caption{Regression Results}
\begin{tabular}{@{\extracolsep{5pt}}lccc}
\\[-1.8ex]\hline
\hline \\[-1.8ex]
Variable & Coefficient & Std. Error & P-Value \\
\hline \\[-1.8ex]
"""

# Loop through coefficients
for var in coef.index:
    latex_table += f"{var} & {coef[var]:.4f} & {stderr[var]:.4f} & {pvalues[var]:.4f} \\\\\n"

# Add R-squared and adjusted R-squared
latex_table += r"""
\hline \\[-1.8ex]
$R^2$ & \multicolumn{3}{c}{""" + f"{rsquared:.4f}" + r"""} \\
\hline
"""

latex_table += f"R-squared (Between) & \\multicolumn{{3}}{{c}}{{{r_squared_between:.4f}}} \\\\ \\hline\n"

latex_table += r"""
\end{tabular}
\end{table}
"""

# Print the LaTeX table
print(latex_table)
# Out:
#           Date   Price Year-Month  Employment       county  Year  Quarter  \
# 0   2011-01-01  504038    2011-01     46346.0  Santa Clara  2011        1
# 1   2011-02-01  500356    2011-02     46806.0  Santa Clara  2011        1
# 2   2011-03-01  498355    2011-03     46824.0  Santa Clara  2011        1
# 3   2011-04-01  495651    2011-04     47189.0  Santa Clara  2011        2
# 4   2011-05-01  491514    2011-05     47737.0  Santa Clara  2011        2
# ..         ...     ...        ...         ...          ...   ...      ...
# 154 2023-11-01  520534    2023-11     39886.0       Travis  2023        4
# 155 2023-12-01  516723    2023-12     39702.0       Travis  2023        4
# 156 2024-01-01  513892    2024-01     38841.0       Travis  2024        1
# 157 2024-02-01  511808    2024-02     38707.0       Travis  2024        1
# 158 2024-03-01  511010    2024-03     38532.0       Travis  2024        1
#
#     Year_Quarter  YQ_2011Q2  YQ_2011Q3  ...  YQ_2021Q4  YQ_2022Q1  YQ_2022Q2  \
# 0         2011Q1      False      False  ...      False      False      False
# 1         2011Q1      False      False  ...      False      False      False
# 2         2011Q1      False      False  ...      False      False      False
# 3         2011Q2       True      False  ...      False      False      False
# 4         2011Q2       True      False  ...      False      False      False
# ..           ...        ...        ...  ...        ...        ...        ...
# 154       2023Q4      False      False  ...      False      False      False
# 155       2023Q4      False      False  ...      False      False      False
# 156       2024Q1      False      False  ...      False      False      False
# 157       2024Q1      False      False  ...      False      False      False
# 158       2024Q1      False      False  ...      False      False      False
#
#      YQ_2022Q3  YQ_2022Q4  YQ_2023Q1  YQ_2023Q2  YQ_2023Q3  YQ_2023Q4  \
# 0        False      False      False      False      False      False
# 1        False      False      False      False      False      False
# 2        False      False      False      False      False      False
# 3        False      False      False      False      False      False
# 4        False      False      False      False      False      False
# ..         ...        ...        ...        ...        ...        ...
# 154      False      False      False      False      False       True
# 155      False      False      False      False      False       True
# 156      False      False      False      False      False      False
# 157      False      False      False      False      False      False
# 158      False      False      False      False      False      False
#
#      YQ_2024Q1
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 154      False
# 155      False
# 156       True
# 157       True
# 158       True
#
# [477 rows x 60 columns]
#                          Price Year-Month  Employment  Year  Quarter  \
# county      Date
# Santa Clara 2011-01-01  504038    2011-01     46346.0  2011        1
#             2011-02-01  500356    2011-02     46806.0  2011        1
#             2011-03-01  498355    2011-03     46824.0  2011        1
#             2011-04-01  495651    2011-04     47189.0  2011        2
#             2011-05-01  491514    2011-05     47737.0  2011        2
# ...                        ...        ...         ...   ...      ...
# Travis      2023-11-01  520534    2023-11     39886.0  2023        4
#             2023-12-01  516723    2023-12     39702.0  2023        4
#             2024-01-01  513892    2024-01     38841.0  2024        1
#             2024-02-01  511808    2024-02     38707.0  2024        1
#             2024-03-01  511010    2024-03     38532.0  2024        1
#
#                        Year_Quarter  YQ_2011Q2  YQ_2011Q3  YQ_2011Q4  \
# county      Date
# Santa Clara 2011-01-01       2011Q1      False      False      False
#             2011-02-01       2011Q1      False      False      False
#             2011-03-01       2011Q1      False      False      False
#             2011-04-01       2011Q2       True      False      False
#             2011-05-01       2011Q2       True      False      False
# ...                             ...        ...        ...        ...
# Travis      2023-11-01       2023Q4      False      False      False
#             2023-12-01       2023Q4      False      False      False
#             2024-01-01       2024Q1      False      False      False
#             2024-02-01       2024Q1      False      False      False
#             2024-03-01       2024Q1      False      False      False
#
#                         YQ_2012Q1  ...  YQ_2021Q4  YQ_2022Q1  YQ_2022Q2  \
# county      Date                   ...
# Santa Clara 2011-01-01      False  ...      False      False      False
#             2011-02-01      False  ...      False      False      False
#             2011-03-01      False  ...      False      False      False
#             2011-04-01      False  ...      False      False      False
#             2011-05-01      False  ...      False      False      False
# ...                           ...  ...        ...        ...        ...
# Travis      2023-11-01      False  ...      False      False      False
#             2023-12-01      False  ...      False      False      False
#             2024-01-01      False  ...      False      False      False
#             2024-02-01      False  ...      False      False      False
#             2024-03-01      False  ...      False      False      False
#
#                         YQ_2022Q3  YQ_2022Q4  YQ_2023Q1  YQ_2023Q2  YQ_2023Q3  \
# county      Date
# Santa Clara 2011-01-01      False      False      False      False      False
#             2011-02-01      False      False      False      False      False
#             2011-03-01      False      False      False      False      False
#             2011-04-01      False      False      False      False      False
#             2011-05-01      False      False      False      False      False
# ...                           ...        ...        ...        ...        ...
# Travis      2023-11-01      False      False      False      False      False
#             2023-12-01      False      False      False      False      False
#             2024-01-01      False      False      False      False      False
#             2024-02-01      False      False      False      False      False
#             2024-03-01      False      False      False      False      False
#
#                         YQ_2023Q4  YQ_2024Q1
# county      Date
# Santa Clara 2011-01-01      False      False
#             2011-02-01      False      False
#             2011-03-01      False      False
#             2011-04-01      False      False
#             2011-05-01      False      False
# ...                           ...        ...
# Travis      2023-11-01       True      False
#             2023-12-01       True      False
#             2024-01-01      False       True
#             2024-02-01      False       True
#             2024-03-01      False       True
#
# [477 rows x 58 columns]
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                  Price   R-squared:                        0.9274
# Estimator:                   PanelOLS   R-squared (Between):              0.9814
# No. Observations:                 477   R-squared (Within):               0.9274
# Date:                Mon, Dec 09 2024   R-squared (Overall):              0.9760
# Time:                        01:07:29   Log-likelihood                   -5887.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      101.47
# Entities:                           3   P-value                           0.0000
# Avg Obs:                       159.00   Distribution:                  F(53,421)
# Min Obs:                       159.00
# Max Obs:                       159.00   F-statistic (robust):             101.47
#                                         P-value                           0.0000
# Time periods:                     159   Distribution:                  F(53,421)
# Avg Obs:                       3.0000
# Min Obs:                       3.0000
# Max Obs:                       3.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Employment     11.418     0.3198     35.704     0.0000      10.789      12.046
# YQ_2011Q2  -1.098e+04  2.784e+04    -0.3943     0.6935   -6.57e+04   4.374e+04
# YQ_2011Q3  -2.322e+04  2.784e+04    -0.8339     0.4048  -7.794e+04   3.151e+04
# YQ_2011Q4  -2.862e+04  2.784e+04    -1.0279     0.3046  -8.334e+04   2.611e+04
# YQ_2012Q1  -2.886e+04  2.784e+04    -1.0366     0.3005  -8.359e+04   2.586e+04
# YQ_2012Q2  -2.443e+04  2.784e+04    -0.8774     0.3808  -7.916e+04    3.03e+04
# YQ_2012Q3  -1.661e+04  2.785e+04    -0.5966     0.5511  -7.135e+04   3.812e+04
# YQ_2012Q4      1348.4  2.785e+04     0.0484     0.9614  -5.339e+04   5.609e+04
# YQ_2013Q1     -7277.8  2.787e+04    -0.2611     0.7941  -6.206e+04   4.751e+04
# YQ_2013Q2     -3247.7  2.788e+04    -0.1165     0.9073  -5.805e+04   5.155e+04
# YQ_2013Q3      1488.7   2.79e+04     0.0534     0.9575  -5.334e+04   5.632e+04
# YQ_2013Q4   1.355e+04   2.79e+04     0.4855     0.6276   -4.13e+04   6.839e+04
# YQ_2014Q1    1.98e+04  2.791e+04     0.7095     0.4784  -3.506e+04   7.467e+04
# YQ_2014Q2   1.549e+04  2.794e+04     0.5544     0.5796  -3.942e+04    7.04e+04
# YQ_2014Q3      7898.3  2.798e+04     0.2823     0.7778  -4.709e+04   6.289e+04
# YQ_2014Q4   1.767e+04  2.799e+04     0.6313     0.5282  -3.735e+04   7.269e+04
# YQ_2015Q1   2.361e+04  2.802e+04     0.8426     0.3999  -3.147e+04   7.869e+04
# YQ_2015Q2   1.984e+04  2.806e+04     0.7073     0.4798  -3.531e+04     7.5e+04
# YQ_2015Q3   2.102e+04   2.81e+04     0.7482     0.4548  -3.421e+04   7.625e+04
# YQ_2015Q4    3.48e+04  2.812e+04     1.2376     0.2166  -2.047e+04   9.006e+04
# YQ_2016Q1   7.081e+04  2.803e+04     2.5259     0.0119   1.571e+04   1.259e+05
# YQ_2016Q2   6.611e+04  2.806e+04     2.3562     0.0189   1.096e+04   1.213e+05
# YQ_2016Q3   4.788e+04   2.81e+04     1.7038     0.0891     -7355.6   1.031e+05
# YQ_2016Q4   3.862e+04  2.812e+04     1.3736     0.1703  -1.665e+04   9.389e+04
# YQ_2017Q1   3.411e+04  2.818e+04     1.2104     0.2268  -2.128e+04    8.95e+04
# YQ_2017Q2   4.121e+04  2.822e+04     1.4604     0.1449  -1.426e+04   9.669e+04
# YQ_2017Q3   2.466e+04  2.832e+04     0.8706     0.3845  -3.102e+04   8.034e+04
# YQ_2017Q4   2.778e+04  2.833e+04     0.9806     0.3274   -2.79e+04   8.346e+04
# YQ_2018Q1    5.34e+04  2.833e+04     1.8852     0.0601     -2279.2   1.091e+05
# YQ_2018Q2   8.464e+04   2.84e+04     2.9805     0.0030   2.882e+04   1.405e+05
# YQ_2018Q3   9.112e+04   2.85e+04     3.1969     0.0015   3.509e+04   1.471e+05
# YQ_2018Q4   9.824e+04  2.852e+04     3.4441     0.0006   4.217e+04   1.543e+05
# YQ_2019Q1   7.844e+04   2.86e+04     2.7425     0.0064   2.222e+04   1.347e+05
# YQ_2019Q2    4.59e+04   2.87e+04     1.5991     0.1106  -1.052e+04   1.023e+05
# YQ_2019Q3   3.407e+04  2.874e+04     1.1852     0.2366  -2.243e+04   9.056e+04
# YQ_2019Q4   3.647e+04  2.876e+04     1.2680     0.2055  -2.007e+04   9.301e+04
# YQ_2020Q1   2.539e+04  2.893e+04     0.8777     0.3806  -3.148e+04   8.226e+04
# YQ_2020Q2   4.002e+04  2.887e+04     1.3865     0.1663  -1.672e+04   9.676e+04
# YQ_2020Q3   3.551e+04   2.89e+04     1.2288     0.2198  -2.129e+04    9.23e+04
# YQ_2020Q4   6.113e+04  2.892e+04     2.1135     0.0351      4278.0    1.18e+05
# YQ_2021Q1   9.093e+04  2.894e+04     3.1425     0.0018   3.406e+04   1.478e+05
# YQ_2021Q2   1.196e+05    2.9e+04     4.1260     0.0000   6.265e+04   1.766e+05
# YQ_2021Q3   1.446e+05  2.909e+04     4.9694     0.0000   8.738e+04   2.017e+05
# YQ_2021Q4   1.621e+05  2.911e+04     5.5679     0.0000   1.049e+05   2.193e+05
# YQ_2022Q1   2.262e+05  2.897e+04     7.8082     0.0000   1.693e+05   2.831e+05
# YQ_2022Q2   2.599e+05  2.911e+04     8.9287     0.0000   2.027e+05   3.171e+05
# YQ_2022Q3   2.517e+05  2.906e+04     8.6599     0.0000   1.945e+05   3.088e+05
# YQ_2022Q4   2.245e+05  2.899e+04     7.7461     0.0000   1.676e+05   2.815e+05
# YQ_2023Q1   2.074e+05  2.894e+04     7.1676     0.0000   1.505e+05   2.643e+05
# YQ_2023Q2   2.072e+05  2.883e+04     7.1858     0.0000   1.505e+05   2.639e+05
# YQ_2023Q3   2.235e+05  2.885e+04     7.7494     0.0000   1.668e+05   2.803e+05
# YQ_2023Q4   2.535e+05  2.879e+04     8.8067     0.0000   1.969e+05   3.101e+05
# YQ_2024Q1   2.669e+05  2.871e+04     9.2951     0.0000   2.104e+05   3.233e+05
# ==============================================================================
#
# F-test for Poolability: 278.20
# P-value: 0.0000
# Distribution: F(2,421)
#
# Included effects: Entity
# R-squared (Between): 0.9813527145647694
#
# \begin{table}[!htbp] \centering
#   \caption{Regression Results}
# \begin{tabular}{@{\extracolsep{5pt}}lccc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
# Variable & Coefficient & Std. Error & P-Value \\
# \hline \\[-1.8ex]
# Employment & 11.4178 & 0.3198 & 0.0000 \\
# YQ_2011Q2 & -10977.6548 & 27837.5462 & 0.6935 \\
# YQ_2011Q3 & -23215.3517 & 27840.4366 & 0.4048 \\
# YQ_2011Q4 & -28616.7123 & 27841.0477 & 0.3046 \\
# YQ_2012Q1 & -28861.1234 & 27841.4883 & 0.3005 \\
# YQ_2012Q2 & -24429.0171 & 27843.0789 & 0.3808 \\
# YQ_2012Q3 & -16612.6954 & 27846.5091 & 0.5511 \\
# YQ_2012Q4 & 1348.3723 & 27847.3491 & 0.9614 \\
# YQ_2013Q1 & -7277.8427 & 27872.1335 & 0.7941 \\
# YQ_2013Q2 & -3247.7125 & 27878.1948 & 0.9073 \\
# YQ_2013Q3 & 1488.6839 & 27895.4246 & 0.9575 \\
# YQ_2013Q4 & 13546.7581 & 27903.7348 & 0.6276 \\
# YQ_2014Q1 & 19803.5034 & 27913.2977 & 0.4784 \\
# YQ_2014Q2 & 15487.9985 & 27936.0384 & 0.5796 \\
# YQ_2014Q3 & 7898.3183 & 27977.4693 & 0.7778 \\
# YQ_2014Q4 & 17671.9515 & 27992.0581 & 0.5282 \\
# YQ_2015Q1 & 23609.7465 & 28020.8635 & 0.3999 \\
# YQ_2015Q2 & 19844.3313 & 28058.3941 & 0.4798 \\
# YQ_2015Q3 & 21022.5282 & 28098.9530 & 0.4548 \\
# YQ_2015Q4 & 34795.2822 & 28115.6128 & 0.2166 \\
# YQ_2016Q1 & 70809.3931 & 28032.8494 & 0.0119 \\
# YQ_2016Q2 & 66108.8981 & 28056.9667 & 0.0189 \\
# YQ_2016Q3 & 47877.1901 & 28099.5098 & 0.0891 \\
# YQ_2016Q4 & 38620.5019 & 28116.8564 & 0.1703 \\
# YQ_2017Q1 & 34109.9583 & 28180.0021 & 0.2268 \\
# YQ_2017Q2 & 41213.8864 & 28220.9756 & 0.1449 \\
# YQ_2017Q3 & 24659.5324 & 28324.9193 & 0.3845 \\
# YQ_2017Q4 & 27777.9392 & 28328.4515 & 0.3274 \\
# YQ_2018Q1 & 53404.1107 & 28328.6953 & 0.0601 \\
# YQ_2018Q2 & 84637.3479 & 28397.2416 & 0.0030 \\
# YQ_2018Q3 & 91115.4457 & 28501.1248 & 0.0015 \\
# YQ_2018Q4 & 98238.7205 & 28524.1208 & 0.0006 \\
# YQ_2019Q1 & 78436.0400 & 28600.6602 & 0.0064 \\
# YQ_2019Q2 & 45898.1076 & 28702.8172 & 0.1106 \\
# YQ_2019Q3 & 34066.5244 & 28742.7669 & 0.2366 \\
# YQ_2019Q4 & 36473.0071 & 28764.3386 & 0.2055 \\
# YQ_2020Q1 & 25392.7237 & 28931.2974 & 0.3806 \\
# YQ_2020Q2 & 40021.7770 & 28866.1495 & 0.1663 \\
# YQ_2020Q3 & 35507.0234 & 28895.2359 & 0.2198 \\
# YQ_2020Q4 & 61130.6725 & 28923.6053 & 0.0351 \\
# YQ_2021Q1 & 90933.4639 & 28936.5011 & 0.0018 \\
# YQ_2021Q2 & 119641.7640 & 28996.7365 & 0.0000 \\
# YQ_2021Q3 & 144566.7907 & 29091.6638 & 0.0000 \\
# YQ_2021Q4 & 162086.2254 & 29110.6092 & 0.0000 \\
# YQ_2022Q1 & 226190.8740 & 28968.2332 & 0.0000 \\
# YQ_2022Q2 & 259889.9034 & 29107.2745 & 0.0000 \\
# YQ_2022Q3 & 251674.5476 & 29062.1831 & 0.0000 \\
# YQ_2022Q4 & 224527.9419 & 28986.0062 & 0.0000 \\
# YQ_2023Q1 & 207417.3576 & 28938.3353 & 0.0000 \\
# YQ_2023Q2 & 207201.2295 & 28834.9993 & 0.0000 \\
# YQ_2023Q3 & 223548.0338 & 28847.1178 & 0.0000 \\
# YQ_2023Q4 & 253517.1463 & 28786.9119 & 0.0000 \\
# YQ_2024Q1 & 266882.5035 & 28712.2212 & 0.0000 \\
#
# \hline \\[-1.8ex]
# $R^2$ & \multicolumn{3}{c}{0.9274} \\
# \hline
# R-squared (Between) & \multicolumn{3}{c}{0.9814} \\ \hline
#
# \end{tabular}
# \end{table}
